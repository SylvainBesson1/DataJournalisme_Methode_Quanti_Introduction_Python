# %% [markdown]
# # M1 Master Datajournalisme Sciences Po Lyon : Méthodes Quantitatives (2025)
# **Sylvain Besson**
# **Ingénieur d'étude en Humanités numériques et traitement de données**
#
# *Maison des Sciences sociales et des Humanités (MSH) Lyon - Saint-Étienne*
# sylvain.besson@msh-lse.fr

# %% [markdown]
# # Introduction

# %% [markdown]
# ## 1. Aperçu du cours
#
#
# Ce cours a pour but de vous introduire à la manipulation de données, à travers de le langage python.
#
# Tout au long de nos trois cours ensembles, nous verrons:
#
# - Les rudiments du fonctionnement du langage python
#
# - La prise en main des environnements de type ***Jupyter Notebook***
#
# - La découverte des bibliothèques de manipulation de données:
#     - Numpy
#     - Pandas
#     - Matplotlib
#     - Seaborn
# - La découverte de bibliothèques de visualisation des données
#
# - Exploitation d'un jeu de données sur Vico (La vie pendant le confinement)
#
#
# La totalité du cours sera de 6 heures, découpée en trois sessions de 2h.
#
# | **mercredi 1 avril 2026** | **mercredi 8 avril 2026** | **mercredi 22 avril 2026** |
# |:-------------------------------:|:-------------------------------:|:-------------------------------:|
# | Introduction du cours et carnets ***Jupyter***     |  Manipuler ses données : Numpy, Pandas | Exploration d'un jeu de données  |
# | Introduction à ***Python***    |  Visualiser ses données : Matplotlib, Seaborn     | Questions  |
#
#
# <br>
#
# Vous pourrez retrouvez l'ensemble des cours sur ce lien: **[https://github.com/SylvainBesson1/DataJournalisme_Methode_Quanti_Introduction_Python](Datajourrnalisme_Methode_Quanti_Introduction_Python)**

# %% [markdown]
# **Installation** écrite par **Alioscha Massein**, Ingénieur d'étude en statistique
#
# *Maison des Sciences sociales et des Humanités (MSH) Lyon - Saint-Étienne*
#
# alioscha.massein@msh-lse.fr
#
# # Préambule
#
# ## Installation de Python
#
# Mais avant, qu'est-ce que c'est que Python ? Python est un langage de programmation, c'est-à-dire un langage qui permet de créer des logiciels, des applications, des sites web, etc. c'est-à-dire un langage un peu compliqué mais accessible pour faire réaliser des tâches à votre ordinateur.
#
# Utiliser un langage de programmation permet tout d'abord de pouvoir réaliser des actions qu'une application tierce ne pourrait pas réaliser, ou bien de créer des applications sur mesure en fonction des tâches que vous souhaitez réaliser. De plus, Python est un des langages de programmation les plus polyvalents et avec une des communautés les plus importantes. Et puisque l'on s'intéresse aux données, ça tombe bien, c'est également un des langages de programmation qui est le plus utilisé pour la *data science*. De nombreux développeurs, entreprises, activistes et journalistes utilisent, développent et mettent à disposition des outils écrits en Python.

# %% [markdown]
# Pour installer Python, nous allons commencer par installer une application que l'on appelle un ***gestionnaire de package***.
#
# Un gestionnaire de package est une application qui permet d'installer, mettre à jour et supprimer des applications qui sont utilisés par votre ordinateur. En pratique, on peut s'en servir pour gérer l'ensemble des applications qui sont installés sur notre ordinateur, mais on s'en sert surtout pour installer de petits utilitaires qui n'ont pas forcément *d'interface graphique*, on parle aussi d'outils en *CLI (command-line interface)*, c'est-à-dire une **interface en ligne de commande**.
#
# Ici, nous n'allons utiliser qu'un gestionnaire de package pour Python, c'est-à-dire un utilitaire qui permet de créer des projets en Python, gérer les versions de Python, et les **librairies** que vous allez utiliser en plus de python (appellées aussi bibliothèques, modules, ou encore... packages, ce sont des outils développés par d'autres personnes que l'on peut réutiliser). Ces derniers temps, un gestionnaire de package Python est de plus en plus utilisé : il s'agit d'un petit outil qui s'appelle [`uv`](https://docs.astral.sh/uv/). `uv` a plusieurs avantages :
# - Il regroupe l'ensemble des autres gestionnaires de paquet Python en une seule interface
# - Il est très, très rapide
# - Il est assez fort pour gérer les conflits de dépendances (certaines versions de librairies peuvent être incompatibles ensembles).

# %% [markdown]
# En fonction de votre **système d'exploitation** (MacOs, Linux, Windows, iOS, Android...), nous n'allons pas installer `uv` de la même manière. Dans tous les cas, vous n'allez pas échapper à votre ***terminal***.
#
# ## Sur Windows
# Si vous êtes sur Windows, vous allez avoir besoin d'ouvrir un outil qui s'appelle **powershell**, que vous trouverez en cherchant dans les applications installées sur votre ordinateur. Powershell est une application qui simule un terminal, et qui execute son propre langage de script (le powershell), qui partage des commandes avec un **shell** classique (bash, zsh, etc.), mais qui embarque aussi ses propres commandes. Pour installer `uv` sur Windows, vous allez taper ou copier dans votre **powershell** :
# ````bash
# powershell -ExecutionPolicy ByPass -c "irm https://astral.sh/uv/install.ps1 | iex"
# ````
#
# En utilisant cette commande, cela devrait installer le gestionnaire de package `uv` sur votre ordinateur. Vous pouvez ensuite l'utiliser sur powershell, ou n'importe quel autre outil de type terminal. On peut vérifier que l'installation s'est déroulée sans problème en testant cette commande :
# ````bash
# uv --version
# ````
# Le résultat devrait être le numéro de version de `uv` que vous avez installé, sous la forme :
# > uv 0.XX.YY (SOMETHING DATE)
#
# ## Linux ou MacOS
#
# Sur Linux ou MacOs, vous pouvez utiliser l'application **terminal** pour ouvrir votre interface en ligne de commande. Sur ces deux système d'exploitation UNIX, vous utilisez un langage qui s'appelle **shell** (bash, zsh, etc.) pour interagir avec votre ordinateur (et le terminal). Pour installer `uv`, vous pouvez utiliser la commande suivante :
# ````bash
# curl -LsSf https://astral.sh/uv/install.sh | sh
# ### If you don't have curl install on your computer
# wget -qO- https://astral.sh/uv/install.sh | sh
# ````
#
# Si tout a bien été installé, vous devriez pouvoir lancer la commande suivante :
#
# ````bash
# uv --version
# ````

# %% [markdown]
# ## Installation de Python
#
# Pour installer, gérer, mettre à jour et supprimer Python, vous pouvez utiliser `uv` très simplement. Dans un terminal (ou un powershell), écrivez cette commande :
# ````bash
# uv python3.12 install
# ````
# En utilisant cette commande, vous installez la version 3.12 de Python, celle que nous allons utiliser ici. Mais vous pourriez installer une autre version si vous le souhaitez. Vous pouvez voir l'ensemble des versions disponibles (et les versions que vous avez installé) à l'aide de la commande suivante :
# ````bash
# uv python list
# ````
#
# Par défaut, il existe une version de Python installé sur la plupart des ordinateurs qui utilisent MacOS.

# %% [markdown]
# ## Installation d'un environnement de développement intégré (IDE)
#
# Sous ce nom un peu compliqué se cache les applications qui permettent de faire de l'édition de code informatique. En pratique le code informatique peut tout à fait s'écrire sur un éditeur de texte classique, comme TextEdit, NotePad++... mais ces logiciels ne proposent pas un environnement complet de programmation qui facilite l'écriture, la gestion, le partage et l'exécution de code informatique.
#
# Dans le cadre de ce cours, nous avons fait le choix de vous faire utiliser l'application [**Visual Studio Code**](https://code.visualstudio.com/), qui est un IDE très utilisé. Sachez néanmoins que VSCode (son petit nom) n'est pas un logiciel libre ou Open source, mais un outil développé et commercialisé par Microsoft. Il existe de nombreuses alternatives à VSCode, comme VSCodium (version *open source* de VScode), Positron, Spyder, Vim (pour les utilisateurs avancés), Emacs,  Atom, etc. Vous êtes libre de travailler avec les outils qui vous correspondent le mieux en terme d'interface ou d'éthique.
#
# Néanmoins, nous vous proposerons ce cours sur l'interface de VSCode, car c'est un outil très utilisé et qui a des mises à jour régulières.
#
# ## Déploiement d'un premier projet Python
#
# Une fois, *uv*, *Python* et *VSCode* installés, vous pouvez créer votre premier projet Python de la manière suivante.
# En premier cliquez sur **Fichier** > **Ouvrir un dossier** et créez un dossier dans lequel vous allez stocker votre projet, ou plutôt ici votre cours. Appelez-le comme vous le souhaitez, nous l'appelerons **coursM1_datajournaliste_python**.
#
# Le dossier créé, vous allez pouvoir ouvrir un terminal en cliquant sur **Terminal** > **Nouveau terminal**. Dans le terminal, nous allons créer un nouveau projet avec *uv*.

# %% [markdown]
# ## Déploiement des librairies depuis un fichier uv.lock ou d'un fichier requirements.txt
#
# Dans certains cas, vous êtes amené à partager et réutiliser du code. Dans la grande majorité des cas, vous utiliserez un petit outil qui s'appelle **git**. **Git** est un outil de gestion de version, ce qui signifie que vous pouvez enregistrer les évolutions d'un fichier dans le temps : fini les V1, V2, V3_Final_presquefini... le second avantage de git, c'est le lien qui est fait avec des *forges logicelles* dont les plus connues sont **GitHub** et **GitLab**. On peut se servir de ces plateformes pour hébeger du code, et de manière générale, pour collaborer à distance.
#
# Dans notre cas, nous allons télécharger le code sans nous servir de **git** car il faudrait installer l'utilitaire sur votre ordinateur. Libre à vous de le faire si vous le souhaitez, mais nous n'aborderons pas ce point ici. Vous pouvez télécharger le dossier du cours au format .zip, et décompresser l'archive zip. Une fois l'archive décompressé, nous allons l'ouvrir avec VSCode afin d'être dans l'environnement du dossier.
#
# Une fois dans le dossier, nous allons créer **l'environnement virtuel** qui permet d'utiliser toutes les librairies du cours, c'est-à-dire l'ensemble des ressources externes que nous allons devoir utiliser en plus de Python. Pour cela, nous pouvons utiliser deux méthodes : soit il existe un fichier **uv.lock** qui précise les librairies à installer avec `uv`, soit il existe un fichier requirements.txt qui permet d'installer les librairies avec un utilitaire qui s'appelle `pip` qui est installé avec Python et avec `uv`.
# #### Si vous avez un fichier uv.lock
# Dans ce cas, c'est très simple. Il vous faut ouvrir un terminal, vérifier que vous êtes bien dans le dossier, et vous pouvez lancer la commande :
# ````bash
# uv sync
# ````
# En executant cette commande, `uv` créé pour vous un environnement virtuel dans un dossier `.venv`, et installe toutes les librairies dont vous aurez besoin pour ce cours.
#
# #### Si vous avez un fichier requirements.txt
# Dans ce cas, il vous faudra dans un premier temps créer l'environnement virtuel en amont :
#
# ````bash
# uv venv #Pour créer l'environnement virtuel
# # Pour activer l'environnement
# source .venv/bin/activate # sur macOS et Linux
# .\venv\Scripts\activate # sur Windows.
#
# uv pip install -r requirements.txt #Pour installer les librairies
# ````
#
# Une fois que vos librairies sont installées, vous pouvez utiliser l'environnement virtuel pour suivre le cours.
#
# ### Encore quelques tips avec uv
#
# `uv` permet donc de gérer les librairies dans un projet python, et de faire pas mal d'autre choses. Voici les principales commandes que nous allons utiliser :
#
# #### Installer et désinstaller des librairies
#
# Vous pouvez gérer les dépendances de votre projet avec deux commandes :
# ````bash
# uv add lalibrairiedevosreves
# uv remove lalibrairienulle
# ````
#
# Vous pouvez voir l'ensemble des commandes disponibles avec `uv` ici :
# ````bash
# uv -h
# #ou
# uv --help
# ````

# %% [markdown]
# # Cours N° 1 : Introduction au langage python

# %% [markdown]
# ## 1. Jupyter Notebook

# %% [markdown]
# Les carnets Jupyter, également appelés *Jupyter Notebook* sont des outils pratiques pour allier prise de note et programmation. Au sein de ces carnets, nous trouvons une structure articulée autour de cellules. Celles-ci peuvent être des cellules de **code**, qui exécuteront le programme que nous y entreront, ou bien des cellules pouvant contenir du ***Markdown***.
#
# La cellule ci-dessous est une cellule de code : pour l'exécuter, cliquez soit sur "Exécuter" dans la barre des commandes en haut, ou bien faites le raccourci clavier Shift+Entrée (ou bien encore Ctrl+Entrée).

# %% [markdown]
# #### Différence entre du Markdown et et du code ?

# %%
# Premier test:
1+1
# Out:
# 2

# %% [markdown]
# Second test:
# Cette cellule, elle, est en Markdown : comme le HTML pour les pages web, le Markdown est un langage de balisage qui se veut néanmoins plus léger. En effet, seules quelques commandes suffisent amplement pour mettre en forme rapidement son texte comme celui que vous lisez actuellement. Pour éditer la cellule, il suffit de double-cliquer sur celle-ci.
#
# Pour votre curiosité, le fichier ***M1_Datajournalisme_Cours_1b_mk_2025.ipynb*** comprend les différentes commandes de mise en forme du texte.
#
# Si vous voulez en apprendre plus encore, vous trouver une [liste exhaustive](https://www.markdownguide.org/cheat-sheet/) de la syntaxe Markdown. De plus des outils tels qu'[Obsidian](https://obsidian.md/)(gratuit, très performant mais propriétaire) ou [Joplin](https://joplinapp.org/fr/) (gratuit et _open-source_) permettre de gérer nativement du markdown et organiser vos notes.

# %% [markdown]
# ## 2. Python : un langage de programmation flexible

# %% [markdown]
# ### Quelques définitions:
# > **Algorithme** : « Un algorithme est une suite finie et non ambiguë d'instructions et d’opérations permettant de résoudre une classe de problèmes. On retrouve aujourd'hui des algorithmes dans de nombreuses applications informatiques, dont dans les systèmes permettant le fonctionnement des ordinateurs » [Wikipédia](https://fr.wikipedia.org/wiki/Algorithme)
#
# Un algorithme est donc suite finie d’opérations. Un parallèle que l'on peut aisement faire, c'est une recette de cuisine. Pour une faire une recette, il faut une liste d'ingrédients puis une suite de préparation à effectuer dans le bonne ordre. Et enfin un plat.
#
# On peut le traduire par:
# `Entrée ->[ Algorithme ]-> Sortie `
# ou
# `Input ->[  Algorithme  ]-> Output`
#
# > **Langage de programmation** : langage interprétable par un ordinateur, et permettant la traduction d’un algorithme.
#
# > **Programme informatique** : traduction d’un algorithme par un langage de programmation.

# %% [markdown]
# ### Python, le langage "*Easy to learn, hard to master*"
# - Syntaxe légère
# - Logique d'écriture suivant le langage naturel (anglais)
# - Langage flexible
# - Puissance des bibliothèques (ou librairies)
# - Fonctionne sur tous les systèmes d'exploitation (MacOS, Windows, Linux)

# %% [markdown]
# Voyons la phrase typique que toute personne commence par écrire en programmation: *Hello World !*
#
# En python, elle est formalisée de la façon suivante: `print("Hello World !")` Vous pouvez la copier dans la cellule suivante et l'excécuter !

# %%
print("Hello World !")
# Out:
# Hello World !

# %% [markdown]
# #### Et dans d'autres langages ?
#
# Java :
# ```Java
# public class Main {
#     public static void main(String[] args) {
#         System.out.println("Hello, World!");
#     }
# }
# ```
# C :
# ```C
# #include <stdio.h>
# int main(void)
# {
#     printf("Hello, World!");
# }
# ```
# C#
# ```C#
# using System;
# class Hello {
#     static void Main(string[] args)
#     {
#         Console.WriteLine("Hello, World!");
#     }
# }
# ```
#
# Cette simple comparaison permet de montrer la simplicité de l'écriture en python.

# %% [markdown]
# ### Quelques concepts... Variables, listes, dictionnaires, boucles, tests, et fonctions

# %% [markdown]
# #### Variables
# >Variable : « Information identifiée par un nom […], et pouvant prendre une ou plusieurs valeurs numériques, logiques ou alphanumériques, au cours du déroulement d'un programme. » [Larousse](https://www.larousse.fr/dictionnaires/francais/variable/81108)

# %%
# Créer une variable

annee = 2026
print(annee)
# Out:
# 2026

# %%
# Une variable peut ... est modifiée

annee = annee + 1
print(annee)
# Out:
# 2027

# %% [markdown]
# #### Types de variables
#
#
# Il existe quatre types de variable en Python:
#
# - **int**, pour les nombres entiers (positifs ou négatifs) -> Ex: 2026, 89, 4, -15
# - **float**, pour les réelles (nombres à virgule) -> Ex: 54.85, -4.2
# - **str**, pour les chaînes de caractères ("textes" au sens large) -> Ex: "Journaux", "temps", "znfsqsqs544555"
# - **bool**, pour les booléens (vrai/faux) -> Ex: True/False, O/N
#
# C'est tout !
#
# On utilisera la commande `type()` pour connaître le type d'une variable, d'une valeur ou d'un objet.

# %%
type(annee)
# Out:
# int

# %% [markdown]
# Faisons le test sur différents types de valeurs:

# %%
print(type(2024))
print(type(-5.89))
print(type("mot"))
print(type("-49"))
print(type("True"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# On voit bien le type de valeur dans `<class 'type'>`

# %%
#Attention aux guillemets et apostrophes !
print('Il l'a vue et à crié "Hey !"')
# Out:
#   Cell In[7], line 2
#     print('Il l'a vue et à crié "Hey !"')
#                                        ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
print("Il l'a vue et à crié "Hey !"")
# Out:
#   Cell In[8], line 1
#     print("Il l'a vue et à crié "Hey !"")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# Si on veut vraiment mettre des apostrophes, c'est possible, il suffit de mettre des \ avant les apostrophes ou les guillemets.

# %%
print('Il l\'a vue et à crié "Hey !"')
print("Il l'a vue et à crié \"Hey !\"")

# %%
# Ceci est un commentaire !
# Il faut seulement mettre un dièse

# %% [markdown]
# Du côté des bonnes pratiques, et même si les notebooks permettent d'expliciter son code assez aisément, il reste particulièrement important de **commenter** régulièrement son code afin de préciser le comportement attendu de ce dernier. Cela est utile autant en travail d'équipe que lorsqu'on reprend son code 6 mois après...

# %% [markdown]
# #### Changer le type d'une variable
# On appliquera simplement des fonctions nommées d'après le type de sortie souhaitée sous la forme :
# `abbreviation_variable(variable_a_convertir)`

# %%
# On reprend la variable annee que l'on a déjà créé

print(annee)
print(type(annee))
# Out:
# 2027
# <class 'int'>

# %%
# C'est donc bien un entier

annee_str = str(annee)
print(annee_str)
print(type(annee_str))
# Out:
# 2027
# <class 'str'>

# %%
# C'est maintenant une chaîne de caractère
print(float(annee))
print(type(float(annee)))
# Out:
# 2027.0
# <class 'float'>

# %% [markdown]
# Le chaine de caractère est devenu un réel, avec un zero après la virgule

# %% [markdown]
# #### Opérations et comparaisons
# On peut réaliser des opérations mathématiques facilement :

# %%
print(2+2)
print(5-3)
print(6*7)
print(13/4)
# Out:
# 4
# 2
# 42
# 3.25

# %%
13//4 # La division entière
# Out:
# 3

# %%
13%4 # Le modulo
# Out:
# 1

# %%
2**4 # La puissance
# Out:
# 16

# %% [markdown]
# #### Les comparaisons

# %% [markdown]
# Maintenant, on peut tester de faire les comparaisons

# %%
2024 == 2025 #Egal ?
# Out:
# False

# %% [markdown]
# `==` permet de comparer deux valeurs et d'indiquer si la comparaison est vraie ou fausse.
#
# ⚠️ **Attention**, `==` est différent de `=` qui signifie affecter une valeur à une variable.

# %%
2024 != 2025 # Inégal ?
# Out:
# True

# %%
2024 < 2025 # Strictement inférieur ?
# Out:
# True

# %%
2024 >= 2025 #Supérieur ou égal ?
# Out:
# False

# %% [markdown]
# #### Les concaténations

# %%
print(2+2)
print("2"+"2")
# Out:
# 4
# 22

# %% [markdown]
# Les deux impressions semblent similaires, la différence de traitement se fait par la type de valeurs.

# %%
print("2"+2) #Attention aux types de variables...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print("2"+2) #Attention aux types de variables...
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# Pour les réaliser des traitements, il faut que les valeurs soient du même type.
#
# Pour réaliser les opérations précédentes, on peut changer leur type de valeurs.

# %%
print("2"+str(2))
print(int("2")+2)
# Out:
# 22
# 4

# %%
lieu = input("Où habitez vous ")
print("Vous habitez à" + lieu +".")
# Out:
# Vous habitez àLyon.

# %% [markdown]
# **`input`** permet de demander à l'utilisateur d'entrer une valeur. La valeur est sauvegarder dans **`age`**. Elle est réutilisé par la suite.

# %% [markdown]
# #### Les listes

# %% [markdown]
# #### Les listes
# Les variables conservent donc jusqu'ici une valeur. Mais comment stocker plusieurs valeurs ? On peut utiliser des **listes**, des **dictionnaires**, des **tuples**, et des **sets**. Ici, nous ne nous intéresserons qu'aux **listes** et **dictionnaires**.
#
# D'abord, créons deux listes :

# %%
#Créer des listes
nombres = [1, 2, 3]
disciplines = ["Science Politique", "Histoire", "Littérature"]

print(nombres)
print(disciplines)
# Out:
# [1, 2, 3]
# ['Science Politique', 'Histoire', 'Littérature']

# %%
#Ajouter un élément à la liste avec append()
nombres.append(4)
disciplines.append("Sociologie") 
#Pas besoin de mettre disciplines = disciplines.append()

print(nombres)
print(disciplines)
# Out:
# [1, 2, 3, 4]
# ['Science Politique', 'Histoire', 'Littérature', 'Sociologie']

# %%
#Connaître la longueur d'une liste avec len()
print(len(nombres))
print(len(disciplines))
# Out:
# 4
# 4

# %% [markdown]
# La liste, stocke des variables dans un ordre nommé "index" : si vous faites la queue dans un magasin, vous êtes au coeur d'une liste de personnes qui attendent. Si deux personnes attendent devant vous, vous êtes donc à la troisième place.
#
#
# **⚠️ Attention**: En Python, on compte à partir de 0... Votre index dans cette file serait donc de 2.

# %%
# Accéder à la première données de langages
print(disciplines[0])
# Out:
# Science Politique

# %% [markdown]
# De la même manière, comment puis-je récupérer le 3 qui est à l'intérieur de ma liste nombres ? Ecrivez ci-dessous :

# %%
print(nombres[2])
# Out:
# 3

# %% [markdown]
# Si je vous disais que `len(disciplines[0])` était égal à 17, sauriez-vous me dire pourquoi ?

# %%
print(len(disciplines[0]))
# Out:
# 17

# %% [markdown]
# Ecrivez votre réponse dans cette cellule (double-cliquez pour l'éditer) -->

# %%
# On peut également supprimer une valeur en utilisant 'del'
del disciplines[0]
print(disciplines)
print(disciplines[0]) #Nouvel index...
# Out:
# ['Littérature', 'Sociologie']
# Littérature

# %% [markdown]
# Petit quiz : en partant de la liste langage actuelle (après suppression de "Science Politique") : qu'est-ce que j'obtiens si je fais `print(disciplines[1][1])` ?

# %%
print(disciplines[1][1])
# Out:
# o

# %% [markdown]
# En partant de cette réponse, il est possible de comprendre les manipulations suivantes :

# %%
phrase = "Ceci est un exemple de phrase"

# %%
print(phrase[:10])
print("\n") 
#Remarquez qu'on retrouve le \ qui modifie le comportement
# Il permet ici de mettre un espace entre deux 'print'
print(phrase[10:])
print("\n")
print(phrase[-10:])
print("\n")
print(phrase[:-10])
# Out:
# Ceci est u
#
#
# n exemple de phrase
#
#
#  de phrase
#
#
# Ceci est un exemple

# %% [markdown]
# #### Dictionnaires
#
# Les listes, en résumé, on les repère via les **[ ]** et l'**index**. Les dictionnaires sont assez similaires mais on les repères cette fois par les **{ }** et les couples **clé/valeur** (exemple: "nom"/"Verne").

# %%
# Créer un dictionnaire vide
# il est toujours nécessaire de créer un dictionnaire pour pouvoir lui attribuer des couples clé/valeur
# Ici un dictionnaire vide4

identite = {}

# %%
# On ajoute des valeurs aux clés
identite["nom"] = "Verne"
identite["prenom"] = "Jules"

# %%
identite
# Out:
# {'nom': 'Verne', 'prenom': 'Jules'}

# %%
identite.keys()
# Out:
# dict_keys(['nom', 'prenom'])

# %%
identite.values()
# Out:
# dict_values(['Verne', 'Jules'])

# %%
identite.items() 
#Exemple d'un résultat sous forme de tuple...
# Out:
# dict_items([('nom', 'Verne'), ('prenom', 'Jules')])

# %% [markdown]
# Retenons simplement des tuples qu'il s'agit de structures semblables à des listes mais dont on ne peut changer les valeurs ou la position des valeurs.
#
# Si on connait déjà les valeurs d'un dictionnaire, on peut aussi le créer directement comme ceci :

# %%
articles = {
    "poire" : 3,
    "pomme" : 2,
    "cerise" : 4,
}

# %%
articles
# Out:
# {'poire': 3, 'pomme': 2, 'cerise': 4}

# %% [markdown]
# Il est mettre une liste dans une liste, une liste dans un dictionnaire, un dictionnaire dans une liste, un dictionnaire dans un dictionnaire... à l'infini...
#
# Créons donc un dictionnaire un peu plus complexe...

# %%
auteurs = {
    'Jules Verne': {
        'annee_naissance': 1828,
        'ville_naissance': 'Nantes',
        'annee_mort': 1905,
        'ville_mort': 'Amiens',
        'ouvrages': [
            'Vingt Mille Lieues sous les mers',
            'Voyage au centre de la Terre',
            'De la Terre à la Lune',
            'Le Tour du monde en quatre-vingt jours',
            "L'Île mystérieuse"
        ]
    },
    'Pénélope Bagieu': {
        'annee_naissance': 1982,
        'ville_naissance': 'Paris',
        'annee_mort': None,
        'ville_mort': None,
        'ouvrages': [
            "Joséphine",
            'Culottées ',
            'La nuit retrouvée',
            'Cadavre exquis'
            ]
    }
}

# %% [markdown]
# D'après vous, que dois-je taper ci-dessous pour accéder uniquement aux informations relatives à Pénélope Bagieu?

# %%
auteurs["Pénélope Bagieu"]
# Out:
# {'annee_naissance': 1982,
#  'ville_naissance': 'Paris',
#  'annee_mort': None,
#  'ville_mort': None,
#  'ouvrages': ['Joséphine',
#   'Culottées ',
#   'La nuit retrouvée',
#   'Cadavre exquis']}

# %% [markdown]
# En vous aidant de la réponse précédente, quelle ligne de code entrer pour obtenir uniquement la liste des ouvrages de Jules Verne ?

# %%
auteurs["Jules Verne"]["ouvrages"]
# Out:
# ['Vingt Mille Lieues sous les mers',
#  'Voyage au centre de la Terre',
#  'De la Terre à la Lune',
#  'Le Tour du monde en quatre-vingt jours',
#  "L'Île mystérieuse"]

# %% [markdown]
# Une dernière ? Que taper pour obtenir en résultat le nom du livre "Cadavre exquis" ?
#
# Non, `print("Cadavre exquis")` ne compte pas !

# %%
auteurs["Pénélope Bagieu"]["ouvrages"][3]
# Out:
# 'Cadavre exquis'

# %% [markdown]
# #### Les tests if / else
# Les tests permettent de vérifier qu'une condition soit remplie pour exécuter du code.
#
# Si telle condition alors telle action
#
# ```python
# if():
#     pass
# ```

# %%
if (5>3):
    print("5 est supérieur à 3")

# %% [markdown]
# Si telle condition alors action 1
# sinon action 2
#
# ```python
# if():
#     pass
# else:
#     pass
# ```

# %%
moyenne = int(input("Moyenne : "))

if (moyenne < 10):
    print('Recalé')
else:
    print('Réussi')

# %% [markdown]
# Si condition 1 alors action 1
# sinon si condition 2 alors action 2
# sinon action 3
#
# ```python
# if () :
#     pass
# elif () :
#     pass
# else:
#     pass
# ```

# %%
reponse = input("Continuer ? y|n")

if (reponse == "y"):
    print('Oui')
elif (reponse == "n"):
    print('Non')
else:
    print('Veuillez entrer "y" ou "n".')

# %%
if ("Hello" in "Hello World"):
    print("La phrase contient le mot")

if ("Hi" not in "Hello World"):
    print("La phrase ne contient pas le mot")

# %% [markdown]
# #### Les boucles
#
# Les boucles permettent de répéter un certain nombre de fois une action.
#
# Elles prennent deux formes : les boucles ***for*** et les boucles ***while***.
#
# ##### *While* : l'équivalent du "tant que"
#
# Les boucles *while* permettent d'effectuer une action tant qu'une condition est remplie et donc égale à True.
#
# On les utilise particulièrement lorsqu'on ne connait pas forcément à l'avance le nombre de fois qu'une action va être répétée avant que la condition soit remplie.

# %%
i = 0
while (i < 10):
    print(i)
    i = i +1

# %% [markdown]
# Ci-dessus, nous connaissons déjà en soi le nombre de fois que la condition va s'éxecuter, mais observons un second exemple où cela n'est pas le cas...

# %%
reponse = input("Entrez un mot : ")
while(reponse != "fini"):
    print(reponse)
    reponse = input("Entrez un mot : ")

print("Bravo ! Fin de programme.")

# %% [markdown]
# Attention, les boucles *while* nécessitent toujours de s'assurer qu'il existe une "sortie", un moment où la condition ne sera plus remplie et où la boucle pourra s'arrêter. Les boucles *while* peuvent en effet être en théorie infinie si leur condition est toujours égale à True...
#
# ```python
# while True:
#     print("Travail terminé!")
# ```
#
# Ici la boucle se répéterait donc à l'infini...

# %% [markdown]
# ##### ***For ... in*** : l'équivalent du "pour"
# Les boucles *for* permettent aussi d'effectuer une action tant qu'une condition est remplie (égale à *True*).
# On les utilise plus souvent quand on connait déjà plus ou moins le nombre de répétition à réaliser.
# Le mot-clé *range* permet notamment de donner une plage de nombre.

# %%
for i in range (0,15):
    print(i)

# %%
for i in auteurs["Pénélope Bagieu"].keys():
    print(i)

# %% [markdown]
# *i* dans la boucle *for* correspond à un élément dans la variable *auteur* avec comme argument/filtre "Pénélope Bagieu" et plus précisent les clés (comme nous l'avons vu précédémment). Ensuite la boucle affiche chaque élément des clés correspondant à "Pénélope Bagieu" dans le dictionnaires des auteur·ices.

# %% [markdown]
# ### Les fonctions
#
# C’est un sous-ensemble d’instructions qui peut être appelé à des moments différents du script.
# Il se caractérise par les deux mots-clés ***def*** et ***return*** : le premier, ***def***, signifiant *definition* permet de créer la fonction, le second de retourner (renvoyer) son résultat.
# ***Return*** n’est pas obligatoire et ne sert que lorsqu'on veut retourner une résultat pour le stocker.
#
# Le fonction prend souvent en compte des paramètres (c'est-à-dire des éléments obligatoires pour la faire fonctionner) mis entre parenthèses.
#
#
# Il faut bien distinguer deux moments dans une fonction :
# 1. Le code qui créé la fonction mais ne l'exécute pas.
# 2. La commande qui appelle la fonction pour l'exécuter.
#
# Exemple avec deux fonctions que vous connaissez déjà...
# ```python
# print("Hello World")
# len(langages)
# ```
# En effet, ces deux commandes **appellent** les fonctions correspondantes (dont nous ne voyons pas le code exact qui est installé avec Python sur votre machine).
# Si nous prenons ***print*** en exemple, nous constatons donc le mot-clé ***print***, qui est le nom de la fonction, et des parenthèses qui encadrent des **paramètres** qui sont spécifiques à la fonction et décidés lors de la création de celle-ci. Ici, les créateurs de la fonction print ont décidé que la fonction afficherait la variable ou tout élément entrée comme paramètre.
#
# Créons une fonction simple...

# %%
def carre(n):
    new_nbr = n**2
    return new_nbr

# %% [markdown]
# La fonction ci-dessus s'appelle **carre** et prend un paramètre ***n*** : en s'exécutant, elle met n au carré dans une variable et la retourne.
# Note à part, nous aurions pu simplifier en faisant simplement :
# ```python
# def carre(n):
#     return n**2
# ```
# Les deux fonctions sont absolument identiques dans leur fonctionnement.
#
# Maintenant, il ne reste plus qu'à l'**appeler** :

# %%
carre(5)

# %%
# Il est possible ensuite de conserver le résultat d'une fonction dans une variable
nb_a_garder = carre(3)
nb_a_garder

# %% [markdown]
# Dans le document ***M1_Datajournalisme_Cours_1c_commandes_2024.ipynb***, vous trouverez un récapitulatif des commandes que nous avons vues jusqu'ici.
#
# ### Exercice récapitulatif :
#
# Etant donné les personnes suivantes :
# - Marie, 10 ans, 1m34
# - Thomas, 27 ans, 1m80
# - Catherine, 61 ans, 1m63
#
#
# Créer, à partir d’un dictionnaire, une fonction qui prendra en paramètre le prénom, l’âge et la taille de chaque personne. Cette fonction imprimera la phrase « [Prénom] est une personne majeure/mineure [faire le test d’âge] et mesure [x]cm »

# %% [markdown]
# <details>
#     <summary>
#         <b>Indice N°1: (pour le lire, <u>cliquez une fois sur cette phrase</u>)</b>
#     </summary>
#     Il y a trois gros morceaux de code dans le script final
#     <ul>
#     <li>La fonction</li>
#     <li>Le ou les dictionnaires de personnes</li>
#     <li>L’appel de la fonction</li>
#     </ul>
#     <details>
#         <summary>
#             <b>Indice N°2 : fil directeur à suivre (pour le lire, <u>cliquez une fois sur cette phrase</u>)</b>
#         </summary>
#         <ul>
#             <li>Oubliez les trois personnes pour le moment ! Avant toute chose, le coeur de l'exercice est de faire s'afficher un message via une fonction qui prend en paramètre le nom, l'age et la taille, peu importe leur valeur. Commencez donc par la fonction !</li>
#             <li>Une fois la déclaration de votre fonction, que faite vous pour passer d'une taille exprimée en m à une taille exprimée en cm ?</li>
#             <li>Testons à présent l'âge ! Ecrivez la phrase attendue pour une personne majeure uniquement si l'âge est supérieur ou égal à 18 !</li>
#             <li>De la même manière, n'écrivez la phrase attendue pour une personne mineure que si l'âge est inférieur à 18 : vous pouvez peut-être ici gagner du temps ?</li>
#             <li>Lorsque votre fonction est terminée, testez là en l'appelant avec les valeurs de votre choix en paramètre : si ça fonctionne, alors vous pouvez vous intéresser de nouveau à nos trois personnes !</li>
#             <li>Créez un dictionnaire "personnes" par exemple, avec à l'intérieur trois clés que sont les prénoms de nos personnages.</li>
#             <li>La valeur en face de chaque clé sera elle-aussi un dictionnaire, avec les deux couples clés-valeurs pour l'âge et pour la taille.</li>
#             <li>Votre dictionnaire est prêt ? Alors il ne vous reste plus qu'à faire une boucle : pour chaque nom et information des personnes présentes dans le dictionnaire principal, appeler la fonction avec les paramètres attendus !</li>
#         </ul>
#     </details>
# </details>

# %% [markdown]
# ### Correction (essayez par vous-même avant !)

# %%
def imprimer(nom, age, taille):
            taille_cm = taille*100
            if age >=18:
                print(nom+ " est une personne majeure et mesure " + str(taille_cm) + "cm")
            else:
                print(nom+ " est une personne mineure et mesure " + str(taille_cm) + "cm")

# %%
##Lorsque votre fonction est prête, rien ne vous empêche de la tester avec des valeurs fictives avant de passer aux personnes demandées...

##Le dictionnaire comprenant les informations sur les personnes
personnes = {
        "Marie":{
            "Age":8,
            "Taille": 1.34
        },
        "Thomas":{
            "Age":34,
            "Taille": 1.87
        },
        "Catherine":{
            "Age":61,
            "Taille": 1.63
            },
        }

##Et enfin, la boucle qui appelle la fonction pour chaque personnes du dictionnaire.    
for nom, infos in personnes.items():
    imprimer(nom, infos["Age"], infos["Taille"])

# %% [markdown]
# Ici dans notre boucle ***for*** nous avons deux éléments qui boucle sur la variable **personnes** de type dictionnaire, **nom** et **infos**. L'élément **nom** boucle sur les clés sur dictionnaire **personnes** et l'éléments infos boucle sur les valeurs de chaque clé "Age" et "Taille".

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Vous avez désormais les bases pour coder en Python : ce langage est également utilisé dans une multitude d'applications, du nettoyage de texte à l'intelligence artificielle, en passant par le web scraping, la constitution de site web ou encore la création de jeux vidéo... Vous avez donc désormais les connaissances de bases d'un langage pouvant vous servir dans le cadre de vos études comme en dehors pour le loisir.

# %% [markdown]
# En prévision du prochain cours, nous allons installer les librairies suivantes :
# > - numpy
# > - pandas
# > - matplotlib
# > - seaborn
#
# Comme indiqué précédemment nous allons utiliser le **gestionnaire de packages** `uv` en faitant la commande:
#
#
#
# Il est possible d'ouvrir un terminal dans VSCode en allant dans la barre d'outils en haut et en cliquant sur terminal puis nouveau terminal. Il faut s'assurer d'avoir l'environnement virtuel activé sinon:
#
# ````bash
# source .venv/bin/activate # sur macOS et Linux
# .\venv\Scripts\activate # sur Windows.
# ````
# Puis ajouter les packages:
#
# ````bash
# uv add numpy pandas matplotlib seaborn
# ````
