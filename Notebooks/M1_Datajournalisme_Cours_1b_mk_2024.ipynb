# %% [markdown]
# # 2.1 Bonus : les commandes Markdown
# ___
# Ci-dessous, vous verrez quelques exemples de mise en forme du texte : pour observer le code qui permet ces "embellissements", double-cliquez simplement sur cette cellule.
#
# Pour sauter une ligne il faut laisser deux espaces
# puis appuyer sur Entrée.
#
# Et ici nous avons commencé un nouveau paragraphe en appuyant deux fois sur Entrée.
# ___
# # Titre de niveau 1
# ## Titre de niveau 2
# ### Titre de niveau 3
# #### Titre de niveau 4
# ##### Titre de niveau 5
# ###### Titre de niveau 6 (minimum)
# ___
# *Italique*
# **Gras**
# ***Gras ET Italique***
# (A chaque fois ici, vous pouvez changer la notation * avec _)
#
# ~~Ce texte sera barré~~
# Exemple de lien en Markdown vers la page du  [Journalisme, data et enquête](https://www.sciencespo-lyon.fr/formations/2e-cycle/specialites-5a/journalisme-data-et-enquete/) !
#
# ___
# ```python
# #Ceci est un bloc de code où nous pouvons simuler du Python (attention, il ne s'exécutera pas, il s'agit seulement d'un outil de démonstration)
#
# for i in range(10):
#     print("N°"+i)
#
# ```
# ___
#
# Pour faire un tableau, il faut adopté une structure comme celle-ci :
#
# | **Colonne 1** |  **Colonne 2** | **Colonne 3** |
# |:-------------------------------:|:-------------------------------:|:-------------------------------:|
# | Item 1   |  Item 2  | Item 3
# | Item 1 col 2   |  Item 2 col 2     | Item 3 col 2  |
# ___
